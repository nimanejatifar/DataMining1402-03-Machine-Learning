# %%
pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
from PIL import Image
from IPython.display import display
img = Image.open('./imgs/pandas1.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x562>

# %% [markdown]
# # Series

# %%
S1 = pd.Series( [5,3,6] )
S1
# Out:
# 0    5
# 1    3
# 2    6
# dtype: int64

# %%
type(S1)
# Out:
# pandas.core.series.Series

# %%
S1.ndim
# Out:
# 1

# %%
S1.shape
# Out:
# (3,)

# %%
S1.size
# Out:
# 3

# %%
print("Summary:")
print(f"ndim ---> {S1.ndim}")
print(f"shape ---> {S1.shape}")
print(f"size ---> {S1.size}")
# Out:
# Summary:
# ndim ---> 1
# shape ---> (3,)
# size ---> 3

# %%
S2 = pd.Series(data=[23,58,21], index=['a', 'b','c'], name='Test_1')
S2
# Out:
# a    23
# b    58
# c    21
# Name: Test_1, dtype: int64

# %%
dictionary = {
    'a': 30,
    'b': 31,
    'c': 32,
    'd': 33,
}

S3 = pd.Series(dictionary)
S3
# Out:
# a    30
# b    31
# c    32
# d    33
# dtype: int64

# %%
np_arr = np.array([12,14,16])
S4 = pd.Series(data=np_arr, index=['a','b','c'], dtype=np.float32)
S4
# Out:
# a    12.0
# b    14.0
# c    16.0
# dtype: float32

# %%
S4.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
S4.values
# Out:
# array([12., 14., 16.], dtype=float32)

# %%
S4.index.name = 'Index'
S4
# Out:
# Index
# a    12.0
# b    14.0
# c    16.0
# dtype: float32

# %%
S4['b']
# Out:
# 14.0

# %%
S4[1]
# Out:
# 14.0

# %%
S4[1:]
# Out:
# Index
# b    14.0
# c    17.0
# dtype: float32

# %%
S4['c']=17
S4
# Out:
# Index
# a    12.0
# b    14.0
# c    17.0
# dtype: float32

# %%
x = ['a','b','c','d','e','f']
y = [16,15,17,15,18,19]

S5 = pd.Series(data=y, index=x)
S5
# Out:
# a    16
# b    15
# c    17
# d    15
# e    18
# f    19
# dtype: int64

# %%
S6 = S5.replace(15,16, inplace=True)
S6
# Out:
# a    16
# b    16
# c    17
# d    16
# e    18
# f    19
# dtype: int64

# %%
S5.replace(15,16, inplace=True)
S5
# Out:
# a    16
# b    16
# c    17
# d    16
# e    18
# f    19
# dtype: int64

# %%
S5.loc['c']
# Out:
# 17

# %%
S5.iloc[2]
# Out:
# 17

# %%
np2 = np.random.randint(10,100,10)
S7 = pd.Series(np2, name='Random numbers')
S7
# Out:
# 0    17
# 1    59
# 2    19
# 3    73
# 4    70
# 5    12
# 6    72
# 7    88
# 8    14
# 9    99
# Name: Random numbers, dtype: int32

# %%
S7[[1,5,6]]
# Out:
# 1    59
# 5    12
# 6    72
# Name: Random numbers, dtype: int32

# %%
S7.head()
# Out:
# 0    17
# 1    59
# 2    19
# 3    73
# 4    70
# Name: Random numbers, dtype: int32

# %%
S7.head(1)
# Out:
# 0    17
# Name: Random numbers, dtype: int32

# %%
S7.tail()
# Out:
# 5    12
# 6    72
# 7    88
# 8    14
# 9    99
# Name: Random numbers, dtype: int32

# %%
S7.tail(1)
# Out:
# 9    99
# Name: Random numbers, dtype: int32

# %%
S7.add_prefix('index__')
# Out:
# index__0    17
# index__1    59
# index__2    19
# index__3    73
# index__4    70
# index__5    12
# index__6    72
# index__7    88
# index__8    14
# index__9    99
# Name: Random numbers, dtype: int32

# %%
S7 >= 50
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: Random numbers, dtype: bool

# %%
S7[S7>=50]
# Out:
# 1    59
# 3    73
# 4    70
# 6    72
# 7    88
# 9    99
# Name: Random numbers, dtype: int32

# %%
S7[S7 % 2 != 0]
# Out:
# 0    17
# 1    59
# 2    19
# 3    73
# 9    99
# Name: Random numbers, dtype: int32

# %%
19 in S7
# Out:
# False

# %%
19 in S7.values
# Out:
# True

# %%
S8 = pd.Series(np.random.randint(1,10,100))
S8
# Out:
# 0     1
# 1     7
# 2     5
# 3     5
# 4     7
#      ..
# 95    1
# 96    6
# 97    5
# 98    4
# 99    2
# Length: 100, dtype: int32

# %%
S8.value_counts()
# Out:
# 2    14
# 7    13
# 1    12
# 6    12
# 3    11
# 8    11
# 5    10
# 9     9
# 4     8
# dtype: int64

# %%
S8.value_counts(sort=False)
# Out:
# 1    12
# 7    13
# 5    10
# 3    11
# 4     8
# 6    12
# 8    11
# 2    14
# 9     9
# dtype: int64

# %%
S8[:10].sort_values()
# Out:
# 0    1
# 5    3
# 6    4
# 2    5
# 3    5
# 7    6
# 1    7
# 4    7
# 9    7
# 8    8
# dtype: int32

# %%
S8[:10].sort_values(ascending=False)
# Out:
# 8    8
# 1    7
# 4    7
# 9    7
# 7    6
# 2    5
# 3    5
# 6    4
# 5    3
# 0    1
# dtype: int32

# %%
S8.unique()
# Out:
# array([1, 7, 5, 3, 4, 6, 8, 2, 9])

# %%
S8[:10].where(S8>=5)
# Out:
# 0    NaN
# 1    7.0
# 2    5.0
# 3    5.0
# 4    7.0
# 5    NaN
# 6    NaN
# 7    6.0
# 8    8.0
# 9    7.0
# dtype: float64

# %%
S8[:10].where(S8>=5, other=0)
# Out:
# 0    0
# 1    7
# 2    5
# 3    5
# 4    7
# 5    0
# 6    0
# 7    6
# 8    8
# 9    7
# dtype: int32

# %%
S2
# Out:
# a    23
# b    58
# c    21
# Name: Test_1, dtype: int64

# %%
S2.min()
# Out:
# 21

# %%
S2.argmin()
# Out:
# 2

# %%
S2.idxmin()
# Out:
# 'c'

# %%
S2.sum()
# Out:
# 102

# %%
S2.mean()
# Out:
# 34.0

# %%
S2.median()
# Out:
# 23.0

# %%
S6
# Out:
# a    16
# b    16
# c    17
# d    16
# e    18
# f    19
# dtype: int64

# %%
S6.nsmallest()
# Out:
# a    16
# b    16
# d    16
# c    17
# e    18
# dtype: int64

# %%
S6.nlargest(2)
# Out:
# f    19
# e    18
# dtype: int64

# %%
S6.quantile(0.25)
# Out:
# 16.0

# %%
S6.quantile(0.75)
# Out:
# 17.75

# %%
S6.describe()
# Out:
# count     6.000000
# mean     17.000000
# std       1.264911
# min      16.000000
# 25%      16.000000
# 50%      16.500000
# 75%      17.750000
# max      19.000000
# dtype: float64

# %%
S6
# Out:
# a    16
# b    16
# c    17
# d    16
# e    18
# f    19
# dtype: int64

# %%
S3
# Out:
# a    30
# b    31
# c    32
# d    33
# dtype: int64

# %%
S6.append(S3)
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_10332\492777871.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S6.append(S3)
# a    16
# b    16
# c    17
# d    16
# e    18
# f    19
# a    30
# b    31
# c    32
# d    33
# dtype: int64

# %%
S3.repeat(2)
# Out:
# a    30
# a    30
# b    31
# b    31
# c    32
# c    32
# d    33
# d    33
# dtype: int64

# %%
S10 = pd.Series([16,14,19,15,9])
S11 = pd.Series([13,12,20,16,10])

# %%
S10.combine(S11, max)
# Out:
# 0    16
# 1    14
# 2    20
# 3    16
# 4    10
# dtype: int64

# %%
S10.combine(S11, min)
# Out:
# 0    13
# 1    12
# 2    19
# 3    15
# 4     9
# dtype: int64

# %%
S10
# Out:
# 0    16
# 1    14
# 2    19
# 3    15
# 4     9
# dtype: int64

# %%
S10.between(0,14)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
S10
# Out:
# 0    16
# 1    14
# 2    19
# 3    15
# 4     9
# dtype: int64

# %%
S10.drop(2)
# Out:
# 0    16
# 1    14
# 3    15
# 4     9
# dtype: int64

# %%
S10.drop(2, inplace=True)

# %%
S10
# Out:
# 0    16
# 1    14
# 3    15
# 4     9
# dtype: int64

# %%
S10.drop([1,3])
# Out:
# 0    16
# 4     9
# dtype: int64

# %%
S10.pop(0)
# Out:
# 16

# %%
S10
# Out:
# 1    14
# 3    15
# 4     9
# dtype: int64

# %%
S12 = pd.Series(data=[3,2,5,np.nan,3,4,np.nan])
S12
# Out:
# 0    3.0
# 1    2.0
# 2    5.0
# 3    NaN
# 4    3.0
# 5    4.0
# 6    NaN
# dtype: float64

# %%
S12.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
S12[S12.isna()]
# Out:
# 3   NaN
# 6   NaN
# dtype: float64

# %%
S12.dropna()
# Out:
# 0    3.0
# 1    2.0
# 2    5.0
# 4    3.0
# 5    4.0
# dtype: float64

# %%
S12
# Out:
# 0    3.0
# 1    2.0
# 2    5.0
# 3    NaN
# 4    3.0
# 5    4.0
# 6    NaN
# dtype: float64

# %%
S12.notna()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
S12.dropna(inplace=True)

# %%
S12
# Out:
# 0    3.0
# 1    2.0
# 2    5.0
# 4    3.0
# 5    4.0
# dtype: float64

# %%
S12.isin([5])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
S12.isin([5]).any()
# Out:
# True

# %%
npR = np.random.randint(10,20, size=20)
S13 = pd.Series(npR)
S13
# Out:
# 0     12
# 1     18
# 2     15
# 3     14
# 4     10
# 5     16
# 6     14
# 7     11
# 8     15
# 9     14
# 10    19
# 11    16
# 12    11
# 13    16
# 14    10
# 15    15
# 16    14
# 17    14
# 18    16
# 19    12
# dtype: int32

# %%
S13.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# dtype: bool

# %%
S13.unique()
# Out:
# array([12, 18, 15, 14, 10, 16, 11, 19])

# %%
S13.drop_duplicates()
# Out:
# 0     12
# 1     18
# 2     15
# 3     14
# 4     10
# 5     16
# 7     11
# 10    19
# dtype: int32

# %%
S12
# Out:
# 0    3.0
# 1    2.0
# 2    5.0
# 3    NaN
# 4    3.0
# 5    4.0
# 6    NaN
# dtype: float64

# %%
numpy = S12.to_numpy()
numpy
# Out:
# array([ 3.,  2.,  5., nan,  3.,  4., nan])

# %%
List = S12.to_list()
List
# Out:
# [3.0, 2.0, 5.0, nan, 3.0, 4.0, nan]

# %%
Str = S12.to_string()
Str
# Out:
# '0    3.0\n1    2.0\n2    5.0\n3    NaN\n4    3.0\n5    4.0\n6    NaN'

# %%
Dict = S12.to_dict()
Dict
# Out:
# {0: 3.0, 1: 2.0, 2: 5.0, 3: nan, 4: 3.0, 5: 4.0, 6: nan}

# %%
S11
# Out:
# 0    13
# 1    12
# 2    20
# 3    16
# 4    10
# dtype: int64

# %%
S11.agg(np.log10) # agg or transform or apply
# Out:
# 0    1.113943
# 1    1.079181
# 2    1.301030
# 3    1.204120
# 4    1.000000
# dtype: float64

# %%
S11.transform(np.log10)
# Out:
# 0    1.113943
# 1    1.079181
# 2    1.301030
# 3    1.204120
# 4    1.000000
# dtype: float64

# %%
S11.apply(np.log10)
# Out:
# 0    1.113943
# 1    1.079181
# 2    1.301030
# 3    1.204120
# 4    1.000000
# dtype: float64

# %%
S11.agg([np.sin, np.cos])
# Out:
#         sin       cos
# 0  0.420167  0.907447
# 1 -0.536573  0.843854
# 2  0.912945  0.408082
# 3 -0.287903 -0.957659
# 4 -0.544021 -0.839072

# %%
S11.agg('min')
# Out:
# 10

# %%
S11.agg(['min', 'max'])
# Out:
# min    10
# max    20
# dtype: int64

# %%
S11.apply(lambda x: x**2)
# Out:
# 0    169
# 1    144
# 2    400
# 3    256
# 4    100
# dtype: int64

# %%
def test(x):
    if x >= 15:
        x = "Big"
    else:
        x = "Small"
        
    return x

# %%
S11.apply(test)
# Out:
# 0    Small
# 1    Small
# 2      Big
# 3      Big
# 4    Small
# dtype: object

# %%
S11
# Out:
# 0    13
# 1    12
# 2    20
# 3    16
# 4    10
# dtype: int64
