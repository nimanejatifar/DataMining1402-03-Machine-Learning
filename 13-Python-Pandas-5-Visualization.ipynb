# %% [markdown]
# # Visualization with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# # Pie

# %%
df['variety'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='variety'>

# %%
df['variety'].value_counts().plot.pie(colors=['g','r','w'],
                                     autopct="%.1f", fontsize=15,
                                     figsize=(4,4));

# %%
# Defining colors for the pie chart 
colors = ['pink', 'silver', 'steelblue'] 
  
# Define the ratio of gap of each fragment in a tuple 
explode = (0.00, 0.00, 0.2) 

# Plotting the pie chart and rotating the pie chart by 60 degrees 
df['variety'].value_counts().plot.pie(colors=colors,
                                     autopct="%.1f", fontsize=15,
                                     figsize=(5,5), explode=explode, shadow=True,
                                     startangle=60);

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                    'radius': [2439.7, 6051.8, 6378.1]},
                   index=['Mercury', 'Venus', 'Earth'])
plot = df.plot.pie(y='mass', figsize=(5, 5))

# %%
plot = df.plot.pie(subplots=True, figsize=(10, 5))

# %% [markdown]
# # Scatter

# %%
df.plot.scatter(x='petal.length', y='petal.width',
               figsize=(10,8));

# %%
df.variety.replace({'Setosa':0,'Versicolor':1,'Virginica':2},
                  inplace=True)

# %%
df.plot.scatter(x='petal.length', y='petal.width',
               c='variety',colormap='cividis',figsize=(10,8),
               s=90);

# %% [markdown]
# # Hist

# %%
df['petal.width'].plot.hist(figsize=(12,8));

# %%
df['petal.width'].plot.hist(bins=20,figsize=(12,8),
                           color='y');

# %% [markdown]
# # Bar

# %%
import numpy as np
df_test = pd.DataFrame(np.random.randint(1,10,size=(10,3)),columns=['a','b','c'])
df_test
# Out:
#    a  b  c
# 0  8  2  1
# 1  5  3  6
# 2  9  4  4
# 3  7  3  5
# 4  8  4  7
# 5  4  2  6
# 6  2  8  9
# 7  3  4  7
# 8  7  1  6
# 9  2  4  6

# %%
df_test.plot.bar(figsize=(16,6));

# %%
df[0:5].plot.bar(figsize=(16,8), alpha=0.7);

# %%
df[0:5].plot.bar(figsize=(16,8), stacked=True);

# %%
df[0:5].plot.bar(figsize=(16,14), subplots=True);

# %% [markdown]
# # Barh

# %%
df[0:5].plot.barh(figsize=(16,8), stacked=False);

# %% [markdown]
# # Area

# %%
df[['sepal.length', 'sepal.width']][0:10]
# Out:
#    sepal.length  sepal.width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
# 5           5.4          3.9
# 6           4.6          3.4
# 7           5.0          3.4
# 8           4.4          2.9
# 9           4.9          3.1

# %%
df[['sepal.length', 'sepal.width']][0:10].plot.area();

# %%
df[['sepal.length', 'sepal.width']][0:10].plot.area(stacked=False);

# %%
df[['sepal.length', 'sepal.width']].plot.area(color='b',stacked=False);

# %%
df.plot.area(stacked=False);

# %% [markdown]
# # Hexbin

# %%
np1 = np.array([2,5,6,2,7,2,5])
np2 = np.array([2,4,7,2,6,2,4])
df_2 = pd.DataFrame({'x': np1, 'y': np2})
df_2
# Out:
#    x  y
# 0  2  2
# 1  5  4
# 2  6  7
# 3  2  2
# 4  7  6
# 5  2  2
# 6  5  4

# %%
df_2.plot.hexbin(x='x',y='y', gridsize=10,
                figsize=(12,8));

# %%
df.plot.hexbin(x='sepal.length',y='sepal.width', gridsize=10,
                figsize=(8,5), title="IRIS dataset");

# %% [markdown]
# # Line

# %%
df['sepal.length'].plot.line(figsize=(12,8));

# %%
df[['sepal.length','sepal.width']].plot.line(figsize=(12,8));

# %%
x = np.linspace(0,10,6)
y = np.power(2, x)
df_test = pd.DataFrame(y, columns=['4^x'])
df_test
# Out:
#       4^x
# 0     1.0
# 1     4.0
# 2    16.0
# 3    64.0
# 4   256.0
# 5  1024.0

# %%
df_test.plot.line(figsize=(8,5),title="4^x");

# %%
x = np.linspace(0,2*np.pi,1000)
y = np.sin(x)
df_test = pd.DataFrame(y, columns=['Sin(x)'])
df_test.plot.line(figsize=(8,5), title="Sin(X)");

# %%
np.random.randn(10)
# Out:
# array([ 0.46709844,  0.51692733, -0.00579378, -1.48525652,  0.75764631,
#         0.22987148, -0.75001251,  0.64289324,  0.16071048, -0.27855131])

# %%
np.random.seed(121)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2024", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot();

# %% [markdown]
# # Box

# %%
df['petal.width'].plot.box();

# %%
df['petal.width'].describe()
# Out:
# count    150.000000
# mean       1.199333
# std        0.762238
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal.width, dtype: float64

# %%
df['petal.width'].plot(kind='box');
